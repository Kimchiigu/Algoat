# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("question-answering", model="Wikidepia/indobert-lite-squad")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\admin\anaconda3\lib\site-packages\transformers\utils\import_utils.py in _get_module(self, module_name)
#    1602         try:
# -> 1603             return importlib.import_module("." + module_name, self.__name__)
#    1604         except Exception as e:
#
# c:\Users\admin\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# c:\Users\admin\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# c:\Users\admin\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# c:\Users\admin\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# c:\Users\admin\anaconda3\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ...
